# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Admin\Downloads\Products.csv')
print(df)
# Out:
#        ProductID                                            Product  \
# 0              1        Original Disinfectant Toilet Cleaner Liquid
# 1              2  Disinfectant Surface & Floor Cleaner Liquid - ...
# 2              3                         Surface Disinfectant Spray
# 3              4  Harpic Disinfectant Toilet Cleaner Original200...
# 4              5  Harpic Toilet Cleaner Liquid - Original 1 L + ...
# ...          ...                                                ...
# 27550      27551                   Canned Sardine - in Tomato Sauce
# 27551      27552                                       Silver Belly
# 27552      27553                             Prawns - Pd Xtra Large
# 27553      27554   Ready to Cook - Large Prawns (Peeled & Deveined)
# 27554      27555                          Tuna Spread In Mayonnaise
#
#        Category_ID          Sub_Category          Brand  Sale_Price  \
# 0             5001  All Purpose Cleaners         Harpic         489
# ...

# %%
df.head()
# Out:
#    ProductID                                            Product  Category_ID  \
# 0          1        Original Disinfectant Toilet Cleaner Liquid         5001
# 1          2  Disinfectant Surface & Floor Cleaner Liquid - ...         5001
# 2          3                         Surface Disinfectant Spray         5001
# 3          4  Harpic Disinfectant Toilet Cleaner Original200...         5001
# 4          5  Harpic Toilet Cleaner Liquid - Original 1 L + ...         5001
#
#            Sub_Category     Brand  Sale_Price  Market_Price  \
# 0  All Purpose Cleaners    Harpic         489           534
# 1  All Purpose Cleaners     Lizol         302           380
# 2  All Purpose Cleaners    Savlon         257           318
# 3  All Purpose Cleaners  bb Combo          74            76
# 4  All Purpose Cleaners  bb Combo         462           558
#
#                             Type
# 0                Toilet Cleaners
# 1         Floor & Other Cleaners
# 2  Disinfectant Spray & Cleaners
# ...

# %%
df.tail()
# Out:
#        ProductID                                           Product  \
# 27550      27551                  Canned Sardine - in Tomato Sauce
# 27551      27552                                      Silver Belly
# 27552      27553                            Prawns - Pd Xtra Large
# 27553      27554  Ready to Cook - Large Prawns (Peeled & Deveined)
# 27554      27555                         Tuna Spread In Mayonnaise
#
#        Category_ID    Sub_Category          Brand  Sale_Price  Market_Price  \
# 27550         5010  Fish & Seafood   Golden Prize          75            79
# 27551         5010  Fish & Seafood  H.S. Dry Fish          45            50
# 27552         5010  Fish & Seafood        Seastar         247           290
# 27553         5010  Fish & Seafood         Buffet         275           305
# 27554         5010  Fish & Seafood   Golden Prize         185           195
#
#                         Type
# 27550         Canned Seafood
# 27551               Dry Fish
# ...

# %%
df.size
# Out:
# 220440

# %%
df.shape
# Out:
# (27555, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     27555 non-null  int64
#  1   Product       27555 non-null  object
#  2   Category_ID   27555 non-null  int64
#  3   Sub_Category  27555 non-null  object
#  4   Brand         27555 non-null  object
#  5   Sale_Price    27555 non-null  int64
#  6   Market_Price  27555 non-null  int64
#  7   Type          27555 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#          ProductID   Category_ID    Sale_Price  Market_Price
# count  27555.00000  27555.000000  27555.000000  27555.000000
# mean   13778.00000   5005.191145    322.532644    382.059154
# std     7954.58767      2.756677    486.260862    581.729219
# min        1.00000   5001.000000      2.000000      3.000000
# 25%     6889.50000   5003.000000     95.000000    100.000000
# 50%    13778.00000   5005.000000    190.000000    220.000000
# 75%    20666.50000   5008.000000    359.000000    425.000000
# max    27555.00000   5011.000000  12500.000000  12500.000000

# %%
df.describe(include ="all").T
# Out:
#                 count unique                           top  freq         mean  \
# ProductID     27555.0    NaN                           NaN   NaN      13778.0
# Product         27555  23533  Turmeric Powder/Arisina Pudi    26          NaN
# Category_ID   27555.0    NaN                           NaN   NaN  5005.191145
# Sub_Category    27555     90                     Skin Care  2294          NaN
# Brand           27555   2314                        Fresho   638          NaN
# Sale_Price    27555.0    NaN                           NaN   NaN   322.532644
# Market_Price  27555.0    NaN                           NaN   NaN   382.059154
# Type            27555    426                     Face Care  1508          NaN
#
#                      std     min     25%      50%      75%      max
# ProductID     7954.58767     1.0  6889.5  13778.0  20666.5  27555.0
# Product              NaN     NaN     NaN      NaN      NaN      NaN
# ...

# %%
df.dtypes
# Out:
# ProductID        int64
# Product         object
# Category_ID      int64
# Sub_Category    object
# Brand           object
# Sale_Price       int64
# Market_Price     int64
# Type            object
# dtype: object

# %%
df.isnull()
# Out:
#        ProductID  Product  Category_ID  Sub_Category  Brand  Sale_Price  \
# 0          False    False        False         False  False       False
# 1          False    False        False         False  False       False
# 2          False    False        False         False  False       False
# 3          False    False        False         False  False       False
# 4          False    False        False         False  False       False
# ...          ...      ...          ...           ...    ...         ...
# 27550      False    False        False         False  False       False
# 27551      False    False        False         False  False       False
# 27552      False    False        False         False  False       False
# 27553      False    False        False         False  False       False
# 27554      False    False        False         False  False       False
#
#        Market_Price   Type
# 0             False  False
# 1             False  False
# ...

# %%
df.isna().any()
# Out:
# ProductID       False
# Product         False
# Category_ID     False
# Sub_Category    False
# Brand           False
# Sale_Price      False
# Market_Price    False
# Type            False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# ProductID       0
# Product         0
# Category_ID     0
# Sub_Category    0
# Brand           0
# Sale_Price      0
# Market_Price    0
# Type            0
# dtype: int64

# %%
# LOC IS SELECTED TO USE ANY LABLES IN COLOUMS 
# THE LABLES OF COLOUMS ARE COLOUMS NAMES

# %%
df.loc[:10,['Market_Price','Sale_Price']]
# Out:
#     Market_Price  Sale_Price
# 0            534         489
# 1            380         302
# 2            318         257
# 3             76          74
# 4            558         462
# 5            362         299
# 6            184         162
# 7            273         247
# 8            273         247
# 9            359         318
# 10           540         483

# %%
df.iloc[:4,:10]
# Out:
#    ProductID                                            Product  Category_ID  \
# 0          1        Original Disinfectant Toilet Cleaner Liquid         5001
# 1          2  Disinfectant Surface & Floor Cleaner Liquid - ...         5001
# 2          3                         Surface Disinfectant Spray         5001
# 3          4  Harpic Disinfectant Toilet Cleaner Original200...         5001
#
#            Sub_Category     Brand  Sale_Price  Market_Price  \
# 0  All Purpose Cleaners    Harpic         489           534
# 1  All Purpose Cleaners     Lizol         302           380
# 2  All Purpose Cleaners    Savlon         257           318
# 3  All Purpose Cleaners  bb Combo          74            76
#
#                             Type
# 0                Toilet Cleaners
# 1         Floor & Other Cleaners
# 2  Disinfectant Spray & Cleaners
# 3                Toilet Cleaners

# %%
# slicing 
df.slicing[0:5]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7204/1470680118.py in <module>
#       1 # slicing
# ----> 2 df.slicing[0:5]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'slicing'

# %%
# Nunique  counts the number of unique entries over the column (or) rows 
# it is very useful in caterogical features.

# %%
# Nunique

# %%
df.nunique()
# Out:
# ProductID       27555
# Product         23533
# Category_ID        11
# Sub_Category       90
# Brand            2314
# Sale_Price       1438
# Market_Price     1229
# Type              426
# dtype: int64

# %%
#MEMERY USAGE

# %%
df.memory_usage()
# Out:
# Index               64
# ProductID       220440
# Product         110220
# Category_ID     220440
# Sub_Category    110220
# Brand           110220
# Sale_Price      220440
# Market_Price    220440
# Type            110220
# dtype: int64

# %%
#SAMPLE
df.sample(n=10)
# Out:
#        ProductID                                            Product  \
# 21171      21172            Plastic Cloth Hangers - Brown, Elegance
# 16581      16582                                      Oil - Mustard
# 21872      21873                        Maxx Pet Container - Yellow
# 18125      18126                  Skin Purifying Jasmine Aroma Mask
# 16150      16151                           Manuka Honey Multifloral
# 8006        8007  Spectra Dual Colour Graduated Dressing Comb - ...
# 14544      14545                                  Chocolate - Chips
# 1090        1091                          Greek Yogurt - Strawberry
# 16222      16223                                Chicken Premium Ham
# 5524        5525              Man - Green Eau De Toilette Deodorant
#
#        Category_ID              Sub_Category            Brand  Sale_Price  \
# 21171         5002     Storage & Accessories          Laplast         159
# ...

# %%
#GROUP FUNCTION 
df[['Product','Sale_Price','Market_Price']].groupby(['Product','Sale_Price','Market_Price']).mean()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df[['Sale_Price','Market_Price']].groupby('Sale_Price').agg(['mean','count'])
# Out:
#             Market_Price
#                     mean count
# Sale_Price
# 2              15.000000     1
# 3               3.000000     1
# 5               5.080000    25
# 6               7.714286     7
# 8               9.333333     3
# ...                  ...   ...
# 7299         7299.000000     1
# 7999        12245.000000     1
# 8184        10769.000000     1
# 10090       10090.000000     1
# 12500       12500.000000     1
#
# [1438 rows x 2 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=27555, step=1)

# %%
df.columns
# Out:
# Index(['ProductID', 'Product', 'Category_ID', 'Sub_Category', 'Brand',
#        'Sale_Price', 'Market_Price', 'Type'],
#       dtype='object')

# %%
#Sorting
#Dataframe by Sorting the index

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#                Brand  Category_ID  Market_Price  \
# 0             Harpic         5001           534
# 1              Lizol         5001           380
# 2             Savlon         5001           318
# 3           bb Combo         5001            76
# 4           bb Combo         5001           558
# ...              ...          ...           ...
# 27550   Golden Prize         5010            79
# 27551  H.S. Dry Fish         5010            50
# 27552        Seastar         5010           290
# 27553         Buffet         5010           305
# 27554   Golden Prize         5010           195
#
#                                                  Product  ProductID  \
# 0            Original Disinfectant Toilet Cleaner Liquid          1
# 1      Disinfectant Surface & Floor Cleaner Liquid - ...          2
# 2                             Surface Disinfectant Spray          3
# 3      Harpic Disinfectant Toilet Cleaner Original200...          4
# ...

# %%
df.sort_values(by = "Sale_Price")
# Out:
#        ProductID                                            Product  \
# 9435        9436                                       Curry Leaves
# 7397        7398                                              Serum
# 2682        2683                     50-50 Timepass Salted Biscuits
# 2763        2764                       Tiger Elaichi Cream Biscuits
# 3145        3146                            Dreams Cup Cake - Choco
# ...          ...                                                ...
# 12256      12257                             Extra Virgin Olive Oil
# 23024      23025  Gas Stove-4 Burner Royale Plus Schott Glass, B...
# 27360      27361                   Epilator SE9-9961 Legs-Body-Face
# 13856      13857      Pet Food - N&D Team Breeder Puppy Top Farmina
# 14051      14052                                    Bravura Clipper
#
#        Category_ID            Sub_Category      Brand  Sale_Price  \
# 9435          5011      Herbs & Seasonings     Fresho           2
# ...

# %%
#nsmallest
df.nsmallest (5,'Market_Price')
# Out:
#       ProductID                         Product  Category_ID  \
# 7397       7398                           Serum         5008
# 1613       1614     Hand Wash - Moisture Shield         5008
# 2591       2592         Good Day Butter Cookies         5006
# 2640       2641  Happy Happy Choco-Chip Cookies         5006
# 2682       2683  50-50 Timepass Salted Biscuits         5006
#
#             Sub_Category      Brand  Sale_Price  Market_Price  \
# 7397           Hair Care      Livon           3             3
# 1613    Bath & Hand Wash     Savlon           5             5
# 2591  Biscuits & Cookies  Britannia           5             5
# 2640  Biscuits & Cookies      Parle           5             5
# 2682  Biscuits & Cookies  Britannia           5             5
#
#                          Type
# 7397         Hair Oil & Serum
# 1613   Hand Wash & Sanitizers
# 2591                  Cookies
# 2640  Glucose & Milk Biscuits
# 2682          Salted Biscuits

# %%
df.nsmallest (5,'Sale_Price')
# Out:
#       ProductID                         Product  Category_ID  \
# 9435       9436                    Curry Leaves         5011
# 7397       7398                           Serum         5008
# 1613       1614     Hand Wash - Moisture Shield         5008
# 2591       2592         Good Day Butter Cookies         5006
# 2640       2641  Happy Happy Choco-Chip Cookies         5006
#
#             Sub_Category      Brand  Sale_Price  Market_Price  \
# 9435  Herbs & Seasonings     Fresho           2            15
# 7397           Hair Care      Livon           3             3
# 1613    Bath & Hand Wash     Savlon           5             5
# 2591  Biscuits & Cookies  Britannia           5             5
# 2640  Biscuits & Cookies      Parle           5             5
#
#                          Type
# 9435    Indian & Exotic Herbs
# 7397         Hair Oil & Serum
# 1613   Hand Wash & Sanitizers
# 2591                  Cookies
# 2640  Glucose & Milk Biscuits

# %%
# nlargest
df.nlargest (5,'Market_Price')
# Out:
#        ProductID                                            Product  \
# 14051      14052                                    Bravura Clipper
# 23024      23025  Gas Stove-4 Burner Royale Plus Schott Glass, B...
# 27360      27361                   Epilator SE9-9961 Legs-Body-Face
# 22994      22995  Gas Stove-3 Burner Royale Plus Schott Glass, B...
# 13856      13857      Pet Food - N&D Team Breeder Puppy Top Farmina
#
#        Category_ID            Sub_Category     Brand  Sale_Price  \
# 14051         5002  Pet Food & Accessories      Wahl       12500
# 23024         5002    Cookware & Non Stick  Prestige        7999
# 27360         5008        Feminine Hygiene     Braun        8184
# 22994         5002    Cookware & Non Stick  Prestige        6999
# 13856         5002  Pet Food & Accessories   Farmina       10090
#
#        Market_Price                     Type
# 14051         12500  Pet Cleaning & Grooming
# 23024         12245                Gas Stove
# ...

# %%
df.nlargest (5,'Sale_Price')
# Out:
#        ProductID                                            Product  \
# 14051      14052                                    Bravura Clipper
# 13856      13857      Pet Food - N&D Team Breeder Puppy Top Farmina
# 27360      27361                   Epilator SE9-9961 Legs-Body-Face
# 23024      23025  Gas Stove-4 Burner Royale Plus Schott Glass, B...
# 12256      12257                             Extra Virgin Olive Oil
#
#        Category_ID            Sub_Category     Brand  Sale_Price  \
# 14051         5002  Pet Food & Accessories      Wahl       12500
# 13856         5002  Pet Food & Accessories   Farmina       10090
# 27360         5008        Feminine Hygiene     Braun        8184
# 23024         5002    Cookware & Non Stick  Prestige        7999
# 12256         5004          Oils & Vinegar    Abbies        7299
#
#        Market_Price                     Type
# 14051         12500  Pet Cleaning & Grooming
# 13856         10090       Pet Meals & Treats
# ...

# %%
# drop_cols
drop_cols = ['Type']
df.drop(drop_cols,axis=1,inplace=True)

# %%
df
# Out:
#        ProductID                                            Product  \
# 0              1        Original Disinfectant Toilet Cleaner Liquid
# 1              2  Disinfectant Surface & Floor Cleaner Liquid - ...
# 2              3                         Surface Disinfectant Spray
# 3              4  Harpic Disinfectant Toilet Cleaner Original200...
# 4              5  Harpic Toilet Cleaner Liquid - Original 1 L + ...
# ...          ...                                                ...
# 27550      27551                   Canned Sardine - in Tomato Sauce
# 27551      27552                                       Silver Belly
# 27552      27553                             Prawns - Pd Xtra Large
# 27553      27554   Ready to Cook - Large Prawns (Peeled & Deveined)
# 27554      27555                          Tuna Spread In Mayonnaise
#
#        Category_ID          Sub_Category          Brand  Sale_Price  \
# 0             5001  All Purpose Cleaners         Harpic         489
# ...

# %%
df.query('100 < Market_Price < 350')[:5]
# Out:
#     ProductID                                            Product  Category_ID  \
# 2           3                         Surface Disinfectant Spray         5001
# 6           7  Super Saver Pack Toilet Cleaner Original, 500m...         5001
# 7           8     Original 1 ltr + Bathroom Cleaner Lemon 500 ml         5001
# 8           9  Disinfectant Toilet Cleaner Liquid - 1 L + Bat...         5001
# 12         13  Lizol Floor Cleaner, Citrus - 500ml + Harpic B...         5001
#
#             Sub_Category     Brand  Sale_Price  Market_Price
# 2   All Purpose Cleaners    Savlon         257           318
# 6   All Purpose Cleaners    Harpic         162           184
# 7   All Purpose Cleaners    Harpic         247           273
# 8   All Purpose Cleaners    Harpic         247           273
# 12  All Purpose Cleaners  bb Combo         172           188

# %%
df.query('40 < Sale_Price < 100')[:8]
# Out:
#     ProductID                                            Product  Category_ID  \
# 3           4  Harpic Disinfectant Toilet Cleaner Original200...         5001
# 22         23  Disinfectant Toilet Cleaner - White & Shine Bl...         5001
# 32         33  Fresh Guard Ocean Fresh Disinfectant Toilet Cl...         5001
# 44         45  Disinfectant Floor & Surface Cleaner - Citrus,...         5001
# 52         53  Disinfectant Floor & Surface Cleaner - Neem, K...         5001
# 56         57                                Phenyle - Cool Cyan         5001
# 59         60                 Phenyle - Black Disinfectant Fluid         5001
# 60         61  Disinfectant Surface & Floor Cleaner Liquid - ...         5001
#
#             Sub_Category     Brand  Sale_Price  Market_Price
# 3   All Purpose Cleaners  bb Combo          74            76
# 22  All Purpose Cleaners    Harpic          77            89
# 32  All Purpose Cleaners     Domex          92           135
# ...

# %%
#new column
new_col=np.random.randn(27555)

#insert the new column at position 8
df.insert (6,'new_col',new_col)

# %%
df.head()
# Out:
#    ProductID                                            Product  Category_ID  \
# 0          1        Original Disinfectant Toilet Cleaner Liquid         5001
# 1          2  Disinfectant Surface & Floor Cleaner Liquid - ...         5001
# 2          3                         Surface Disinfectant Spray         5001
# 3          4  Harpic Disinfectant Toilet Cleaner Original200...         5001
# 4          5  Harpic Toilet Cleaner Liquid - Original 1 L + ...         5001
#
#            Sub_Category     Brand  Sale_Price   new_col  Market_Price
# 0  All Purpose Cleaners    Harpic         489  0.140751           534
# 1  All Purpose Cleaners     Lizol         302 -1.186199           380
# 2  All Purpose Cleaners    Savlon         257 -1.158088           318
# 3  All Purpose Cleaners  bb Combo          74 -1.230820            76
# 4  All Purpose Cleaners  bb Combo         462  0.637482           558
