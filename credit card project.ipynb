# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os

# %%
spend = pd.read_csv(r'C:\Users\Admin\Downloads\spend.csv')
repayment = pd.read_csv(r'C:\Users\Admin\Downloads\Repayment.csv')
customer = pd.read_csv(r'C:\Users\Admin\Downloads\Customer Acqusition.csv')
print(spend)
print(repayment)
print(customer)
# Out:
#       Sl No: Customer      Month        Type     Amount
# 0          1       A1  12-Jan-04   JEWELLERY  485470.80
# 1          2       A1   3-Jan-04       PETRO  410556.13
# 2          3       A1  15-Jan-04     CLOTHES   23740.46
# 3          4       A1  25-Jan-04        FOOD  484342.47
# 4          5       A1  17-Jan-05      CAMERA  369694.07
# ...      ...      ...        ...         ...        ...
# 1495    1496      A67   4-Feb-06  BUS TICKET  356872.73
# 1496    1497      A68  25-Mar-06  BUS TICKET  204971.10
# 1497    1498      A69  31-Mar-06  BUS TICKET   50449.44
# 1498    1499      A70  23-Mar-06  BUS TICKET   80593.94
# 1499    1500      A71  24-Mar-06  BUS TICKET  194447.62
#
# [1500 rows x 5 columns]
#       SL No: Customer      Month     Amount  Unnamed: 4
# 0        NaN       A1  12-Jan-04  495414.75         NaN
# 1        2.0       A1   3-Jan-04  245899.02         NaN
# 2        3.0       A1  15-Jan-04  259490.06         NaN
# ...

# %%
spend.head()
# Out:
#    Sl No: Customer      Month       Type     Amount
# 0       1       A1  12-Jan-04  JEWELLERY  485470.80
# 1       2       A1   3-Jan-04      PETRO  410556.13
# 2       3       A1  15-Jan-04    CLOTHES   23740.46
# 3       4       A1  25-Jan-04       FOOD  484342.47
# 4       5       A1  17-Jan-05     CAMERA  369694.07

# %%
spend.tail()
# Out:
#       Sl No: Customer      Month        Type     Amount
# 1495    1496      A67   4-Feb-06  BUS TICKET  356872.73
# 1496    1497      A68  25-Mar-06  BUS TICKET  204971.10
# 1497    1498      A69  31-Mar-06  BUS TICKET   50449.44
# 1498    1499      A70  23-Mar-06  BUS TICKET   80593.94
# 1499    1500      A71  24-Mar-06  BUS TICKET  194447.62

# %%
repayment.head()
# Out:
#    SL No: Customer      Month     Amount  Unnamed: 4
# 0     NaN       A1  12-Jan-04  495414.75         NaN
# 1     2.0       A1   3-Jan-04  245899.02         NaN
# 2     3.0       A1  15-Jan-04  259490.06         NaN
# 3     4.0       A1  25-Jan-04  437555.12         NaN
# 4     5.0       A1  17-Jan-05  165972.88         NaN

# %%
repayment.tail()
# Out:
#       SL No: Customer Month  Amount  Unnamed: 4
# 1518     NaN      NaN   NaN     NaN         NaN
# 1519     NaN      NaN   NaN     NaN         NaN
# 1520     NaN      NaN   NaN     NaN         NaN
# 1521     NaN      NaN   NaN     NaN         NaN
# 1522     NaN      NaN   NaN     NaN         NaN

# %%
customer.head()
# Out:
#    No Customer  Age       City   Product     Limit Company        Segment
# 0   1       A1   76  BANGALORE      Gold  500000.0      C1  Self Employed
# 1   2       A2   71   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2   3       A3   34     COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3   4       A4   47     BOMBAY  Platimum   10001.0      C4           Govt
# 4   5       A5   56  BANGALORE  Platimum   10002.0      C5  Normal Salary

# %%
customer.tail()
# Out:
#      No Customer  Age        City   Product     Limit Company        Segment
# 95   96      A96   54     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96   97      A97   58  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97   98      A98   51    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98   99      A99   35    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99  100     A100   36      COCHIN    Silver  100000.0      C5   Salaried_MNC

# %%
spend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sl No:    1500 non-null   int64
#  1   Customer  1500 non-null   object
#  2   Month     1500 non-null   object
#  3   Type      1500 non-null   object
#  4   Amount    1500 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.1+ KB

# %%
repayment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1523 entries, 0 to 1522
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SL No:      1499 non-null   float64
#  1   Customer    1500 non-null   object
#  2   Month       1500 non-null   object
#  3   Amount      1500 non-null   float64
#  4   Unnamed: 4  0 non-null      float64
# dtypes: float64(3), object(2)
# memory usage: 47.7+ KB

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No        100 non-null    int64
#  1   Customer  100 non-null    object
#  2   Age       100 non-null    int64
#  3   City      100 non-null    object
#  4   Product   100 non-null    object
#  5   Limit     100 non-null    float64
#  6   Company   100 non-null    object
#  7   Segment   100 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 4.4+ KB

# %%
spend.shape
# Out:
# (1500, 5)

# %%
repayment.shape
# Out:
# (1523, 5)

# %%
customer.shape
# Out:
# (100, 8)

# %%
spend.size
# Out:
# 7500

# %%
repayment.size
# Out:
# 7615

# %%
customer.size
# Out:
# 800

# %%
spend.describe()
# Out:
#             Sl No:         Amount
# count  1500.000000    1500.000000
# mean    750.500000  243096.049460
# std     433.157015  141349.547367
# min       1.000000     720.300000
# 25%     375.750000  122606.487500
# 50%     750.500000  239210.360000
# 75%    1125.250000  361617.632500
# max    1500.000000  499793.490000

# %%
repayment.describe()
# Out:
#            SL No:         Amount  Unnamed: 4
# count  1499.00000    1500.000000         0.0
# mean    751.00000  247890.054420         NaN
# std     432.86834  145290.382733         NaN
# min       2.00000      55.860000         NaN
# 25%     376.50000  118604.905000         NaN
# 50%     751.00000  248008.185000         NaN
# 75%    1125.50000  367236.890000         NaN
# max    1500.00000  499930.660000         NaN

# %%
customer.describe()
# Out:
#                No         Age          Limit
# count  100.000000  100.000000     100.000000
# mean    50.500000   46.490000  284700.610000
# std     29.011492   18.282572  218494.967852
# min      1.000000   12.000000   10000.000000
# 25%     25.750000   33.750000  100000.000000
# 50%     50.500000   46.500000  300001.500000
# 75%     75.250000   60.250000  500000.000000
# max    100.000000   79.000000  500000.000000

# %%
spend.describe(include = "all").T
# Out:
#            count unique        top freq          mean            std    min  \
# Sl No:    1500.0    NaN        NaN  NaN         750.5     433.157015    1.0
# Customer    1500    100        A61   38           NaN            NaN    NaN
# Month       1500     74  12-Jan-04   80           NaN            NaN    NaN
# Type        1500     15      PETRO  200           NaN            NaN    NaN
# Amount    1500.0    NaN        NaN  NaN  243096.04946  141349.547367  720.3
#
#                   25%        50%          75%        max
# Sl No:         375.75      750.5      1125.25     1500.0
# Customer          NaN        NaN          NaN        NaN
# Month             NaN        NaN          NaN        NaN
# Type              NaN        NaN          NaN        NaN
# Amount    122606.4875  239210.36  361617.6325  499793.49

# %%
repayment.describe(include = "all").T
# Out:
#              count unique        top freq          mean            std    min  \
# SL No:      1499.0    NaN        NaN  NaN         751.0      432.86834    2.0
# Customer      1500    100        A61   38           NaN            NaN    NaN
# Month         1500     74  12-Jan-04   73           NaN            NaN    NaN
# Amount      1500.0    NaN        NaN  NaN  247890.05442  145290.382733  55.86
# Unnamed: 4     0.0    NaN        NaN  NaN           NaN            NaN    NaN
#
#                    25%         50%        75%        max
# SL No:           376.5       751.0     1125.5     1500.0
# Customer           NaN         NaN        NaN        NaN
# Month              NaN         NaN        NaN        NaN
# Amount      118604.905  248008.185  367236.89  499930.66
# Unnamed: 4         NaN         NaN        NaN        NaN

# %%
customer.describe(include = "all").T
# Out:
#           count unique     top freq       mean            std      min  \
# No        100.0    NaN     NaN  NaN       50.5      29.011492      1.0
# Customer    100    100      A1    1        NaN            NaN      NaN
# Age       100.0    NaN     NaN  NaN      46.49      18.282572     12.0
# City        100      8  COCHIN   20        NaN            NaN      NaN
# Product     100      3    Gold   38        NaN            NaN      NaN
# Limit     100.0    NaN     NaN  NaN  284700.61  218494.967852  10000.0
# Company     100     41     C21    4        NaN            NaN      NaN
# Segment     100      5    Govt   29        NaN            NaN      NaN
#
#                25%       50%       75%       max
# No           25.75      50.5     75.25     100.0
# Customer       NaN       NaN       NaN       NaN
# Age          33.75      46.5     60.25      79.0
# City           NaN       NaN       NaN       NaN
# Product        NaN       NaN       NaN       NaN
# ...

# %%
spend.isnull()
# Out:
#       Sl No:  Customer  Month   Type  Amount
# 0      False     False  False  False   False
# 1      False     False  False  False   False
# 2      False     False  False  False   False
# 3      False     False  False  False   False
# 4      False     False  False  False   False
# ...      ...       ...    ...    ...     ...
# 1495   False     False  False  False   False
# 1496   False     False  False  False   False
# 1497   False     False  False  False   False
# 1498   False     False  False  False   False
# 1499   False     False  False  False   False
#
# [1500 rows x 5 columns]

# %%
repayment.isnull()
# Out:
#       SL No:  Customer  Month  Amount  Unnamed: 4
# 0       True     False  False   False        True
# 1      False     False  False   False        True
# 2      False     False  False   False        True
# 3      False     False  False   False        True
# 4      False     False  False   False        True
# ...      ...       ...    ...     ...         ...
# 1518    True      True   True    True        True
# 1519    True      True   True    True        True
# 1520    True      True   True    True        True
# 1521    True      True   True    True        True
# 1522    True      True   True    True        True
#
# [1523 rows x 5 columns]

# %%
customer.isnull()
# Out:
#        No  Customer    Age   City  Product  Limit  Company  Segment
# 0   False     False  False  False    False  False    False    False
# 1   False     False  False  False    False  False    False    False
# 2   False     False  False  False    False  False    False    False
# 3   False     False  False  False    False  False    False    False
# 4   False     False  False  False    False  False    False    False
# ..    ...       ...    ...    ...      ...    ...      ...      ...
# 95  False     False  False  False    False  False    False    False
# 96  False     False  False  False    False  False    False    False
# 97  False     False  False  False    False  False    False    False
# 98  False     False  False  False    False  False    False    False
# 99  False     False  False  False    False  False    False    False
#
# [100 rows x 8 columns]

# %%
spend.isna().any()
# Out:
# Sl No:      False
# Customer    False
# Month       False
# Type        False
# Amount      False
# dtype: bool

# %%
repayment.isna().any()
# Out:
# SL No:        True
# Customer      True
# Month         True
# Amount        True
# Unnamed: 4    True
# dtype: bool

# %%
repayment.dropna(inplace = True)

# %%
customer.isna().any()
# Out:
# No          False
# Customer    False
# Age         False
# City        False
# Product     False
# Limit       False
# Company     False
# Segment     False
# dtype: bool

# %%
spend.isnull().sum()
# Out:
# Sl No:      0
# Customer    0
# Month       0
# Type        0
# Amount      0
# dtype: int64

# %%
repayment.isnull().sum()
# Out:
# SL No:        0.0
# Customer      0.0
# Month         0.0
# Amount        0.0
# Unnamed: 4    0.0
# dtype: float64

# %%
customer.isnull().sum()
# Out:
# No          0
# Customer    0
# Age         0
# City        0
# Product     0
# Limit       0
# Company     0
# Segment     0
# dtype: int64

# %%
#In case age is less than 18, replace it with mean of age values.

# %%
customer.head()
# Out:
#    No Customer  Age       City   Product     Limit Company        Segment
# 0   1       A1   76  BANGALORE      Gold  500000.0      C1  Self Employed
# 1   2       A2   71   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2   3       A3   34     COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3   4       A4   47     BOMBAY  Platimum   10001.0      C4           Govt
# 4   5       A5   56  BANGALORE  Platimum   10002.0      C5  Normal Salary

# %%
customer["Age"].mean()
# Out:
# 46.49

# %%
customer.loc[custmer["Age"] < 18,"Age"] = custmer["Age"].mean()

# %%
mean_new = customer["Age"].mean()
print("the new_mean of age coloum is ",mean_new)
# Out:
# the new_mean of age coloum is  46.49

# %%
custmer.loc[customer["Age"]< 18,"Age"]
# Out:
# 13    46.49
# 40    46.49
# 62    46.49
# 67    46.49
# 69    46.49
# 89    46.49
# Name: Age, dtype: float64

# %%
print("All the custmers who have aged less than 18 have been replaced by mean of the age coloumns.")
# Out:
# All the custmers who have aged less than 18 have been replaced by mean of the age coloumns.

# %%
#b. In case spend amount is more than the limit, replace it with 50% of that customer’s limit.
#(customer’s limit provided in acquisition table is the per transaction limit on his card)

# %%
spend.head(3)
# Out:
#    Sl No: Customer      Month       Type     Amount
# 0       1       A1  12-Jan-04  JEWELLERY  485470.80
# 1       2       A1   3-Jan-04      PETRO  410556.13
# 2       3       A1  15-Jan-04    CLOTHES   23740.46

# %%
customer.head(3)
# Out:
#    No Customer   Age       City   Product     Limit Company        Segment
# 0   1       A1  76.0  BANGALORE      Gold  500000.0      C1  Self Employed
# 1   2       A2  71.0   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2   3       A3  34.0     COCHIN  Platimum   10000.0      C3   Salaried_Pvt

# %%
customer_spend = pd.merge(left =customer ,right = spend,on = "Customer",how ="inner")

# %%
customer_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount
# 0       1  12-Jan-04  JEWELLERY  485470.80
# 1       2   3-Jan-04      PETRO  410556.13
# 2       3  15-Jan-04    CLOTHES   23740.46
# 3       4  25-Jan-04       FOOD  484342.47
# 4       5  17-Jan-05     CAMERA  369694.07

# %%
customer_spend.shape
# Out:
# (1500, 12)

# %%
customer_spend[custmer_spend["Amount"] > customer_spend["Limit"]]
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 18      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 19      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 20      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 21      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 22      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# ...   ...      ...   ...         ...       ...       ...     ...
# 1486   87      A87  27.0    CALCUTTA    Silver  100003.0     C10
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month          Type     Amount
# 18     Salaried_MNC     104   3-Jan-04        RENTAL  199554.72
# ...

# %%
#In case spend amount is more than the limit, replace it with 50% of that customer’s limit
customer_spend.loc[custmer_spend["Amount"] > customer_spend["Limit"],"Amount"] = (50 * custmer_spend["Limit"]).div(100)

# %%
# there are no custmers left whose spend amount is more than limit
customer_spend[custmer_spend["Amount"] > customer_spend["Limit"]]
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 18      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 19      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 20      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 21      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 22      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# ...   ...      ...   ...         ...       ...       ...     ...
# 1486   87      A87  27.0    CALCUTTA    Silver  100003.0     C10
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month          Type   Amount
# 18     Salaried_MNC     104   3-Jan-04        RENTAL  50000.0
# ...

# %%
#c. Incase the repayment amount is more than the limit, replace the repayment with the limit.

# %%
customer.head()
# Out:
#    No Customer   Age       City   Product     Limit Company        Segment
# 0   1       A1  76.0  BANGALORE      Gold  500000.0      C1  Self Employed
# 1   2       A2  71.0   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2   3       A3  34.0     COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3   4       A4  47.0     BOMBAY  Platimum   10001.0      C4           Govt
# 4   5       A5  56.0  BANGALORE  Platimum   10002.0      C5  Normal Salary

# %%
repayment.head()
# Out:
#    SL No: Customer      Month     Amount  Unnamed: 4
# 0     NaN       A1  12-Jan-04  495414.75         NaN
# 1     2.0       A1   3-Jan-04  245899.02         NaN
# 2     3.0       A1  15-Jan-04  259490.06         NaN
# 3     4.0       A1  25-Jan-04  437555.12         NaN
# 4     5.0       A1  17-Jan-05  165972.88         NaN

# %%
customer_repayment = pd.merge(left = repayment ,right = customer,on = "Customer",how ="inner")

# %%
customer_repayment[customer_repayment["Amount"] > customer_repayment["Limit"]]
# Out:
#       SL No: Customer      Month     Amount  Unnamed: 4  No   Age    City  \
# 18       8.0       A8   5-Feb-04  156913.59         NaN   8  67.0   PATNA
# 19     110.0       A8  12-Jan-04  350999.98         NaN   8  67.0   PATNA
# 20     124.0       A8  31-Mar-06  155642.95         NaN   8  67.0   PATNA
# 21     138.0       A8   9-May-05  145457.38         NaN   8  67.0   PATNA
# 22     152.0       A8   8-May-06  361184.89         NaN   8  67.0   PATNA
# ...      ...      ...        ...        ...         ...  ..   ...     ...
# 1494   259.0       A7   6-May-06  400375.97         NaN   7  26.0  COCHIN
# 1496   295.0       A7   3-Dec-05  429700.12         NaN   7  26.0  COCHIN
# 1497   313.0       A7  23-Feb-05  344628.72         NaN   7  26.0  COCHIN
# 1498   331.0       A7  31-Mar-06  336264.37         NaN   7  26.0  COCHIN
# 1499   349.0       A7   3-Jan-04  473662.61         NaN   7  26.0  COCHIN
#
#      Product     Limit Company       Segment
# ...

# %%
#a. How many distinct customers exist?
distnct_customers = customer["Customer"].nunique()
print("number of distinct customers are",distnct_customers)
# Out:
# number of distinct customers are 100

# %%
#b.How many distinct categories exist?

# %%
customer["Segment"].value_counts()
# Out:
# Govt             29
# Self Employed    23
# Normal Salary    22
# Salaried_MNC     13
# Salaried_Pvt     13
# Name: Segment, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot('Segment',data = customer)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print( "we can see countplot that number of distinct categories are",len(customer["Segment"].value_counts()))
# Out:
# we can see countplot that number of distinct categories are 5

# %%
#c. What is the average monthly spend by customers?

# %%
spend['Monthly'] = spend['Month'].apply(lambda X:pd.Timestamp.strftime(X,format = "%B"))
spend['Yearly'] = spend['Month'].apply(lambda X:pd.Timestamp.strftime(X,format = "%Y"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13708/3322418458.py in <module>
# ----> 1 spend['Monthly'] = spend['Month'].apply(lambda X:pd.Timestamp.strftime(X,format = "%B"))
#       2 spend['Yearly'] = spend['Month'].apply(lambda X:pd.Timestamp.strftime(X,format = "%Y"))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ...
